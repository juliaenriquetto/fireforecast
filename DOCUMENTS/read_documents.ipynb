# %%
import csv

# %%
with open('modis_2022_Brazil.csv', 'r', encoding='utf-8') as ficheiro:
    reader = csv.reader(ficheiro)
    
    # Pula a primeira linha (cabeçalho)
    next(reader)
    
    for linha in reader:
        # Lê apenas as duas primeiras colunas
        colunas = linha[:2]
        print(colunas)
# Out:
# ['-23.1626', '-53.7109']
# ['-23.3932', '-53.8741']
# ['-23.3858', '-53.8703']
# ['-20.237', '-56.6381']
# ['-20.2169', '-56.6297']
# ['-20.2252', '-56.6405']
# ['-20.2317', '-56.6447']
# ['-18.4374', '-55.525']
# ['-20.2401', '-56.6554']
# ['-20.222', '-56.6232']
# ['-11.1309', '-60.863']
# ['-12.0403', '-64.1053']
# ['-9.6522', '-65.7549']
# ['2.8494', '-60.5109']
# ['2.8469', '-60.4942']
# ['2.844', '-60.5158']
# ['-23.1586', '-53.7074']
# ['-23.1601', '-53.7127']
# ['-7.5565', '-63.2677']
# ['-9.2236', '-44.5908']
# ['-20.9014', '-53.7817']
# ['-21.1862', '-53.2409']
# ['-19.7134', '-56.2193']
# ['-19.7026', '-56.2173']
# ['-20.2447', '-56.614']
# ['-20.9981', '-51.7928']
# ['-20.2446', '-56.6206']
# ['-26.4548', '-48.7858']
# ['-23.1581', '-53.7227']
# ['-23.1597', '-53.7126']
# ['-23.1688', '-53.7143']
# ['-23.1703', '-53.7042']
# ['-23.383', '-53.8742']
# ['-23.3906', '-53.8859']
# ['-23.3921', '-53.8758']
# ['-23.3997', '-53.8876']
# ['-25.5633', '-51.4782']
# ...
